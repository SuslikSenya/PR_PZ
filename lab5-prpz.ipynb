# %%
import os
import json
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

DATASET_DIR = "/kaggle/input/lab5-dataset/dataset/train" 
TEST_DIR = "/kaggle/input/lab5-dataset/dataset/test"  
IMG_SIZE = (299, 299)
BATCH_SIZE = 32
EPOCHS = 20
LR = 1e-4
MODEL_PATH = "inception_like_binary.h5"
CLASS_INDICES_JSON = "class_indices.json"
METADATA_JSON = "metadata.json"

def create_generators(dataset_dir=DATASET_DIR):
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=30,
        width_shift_range=0.12,
        height_shift_range=0.12,
        shear_range=0.12,
        zoom_range=0.12,
        horizontal_flip=True,
        fill_mode='nearest',
        validation_split=0.2
    )
    train_gen = train_datagen.flow_from_directory(
        dataset_dir,
        target_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='binary',
        subset='training',
        shuffle=True
    )
    val_gen = train_datagen.flow_from_directory(
        dataset_dir,
        target_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='binary',
        subset='validation',
        shuffle=False
    )
    with open(CLASS_INDICES_JSON, "w", encoding="utf-8") as f:
        json.dump(train_gen.class_indices, f, ensure_ascii=False, indent=2)
    return train_gen, val_gen

def inception_module(x,
                     filters_1x1,
                     filters_3x3_reduce, filters_3x3,
                     filters_5x5_reduce, filters_5x5,
                     filters_pool_proj,
                     name=None):
    branch1 = layers.Conv2D(filters_1x1, (1,1), padding='same', activation='relu')(x)
    branch3 = layers.Conv2D(filters_3x3_reduce, (1,1), padding='same', activation='relu')(x)
    branch3 = layers.Conv2D(filters_3x3, (3,3), padding='same', activation='relu')(branch3)
    branch5 = layers.Conv2D(filters_5x5_reduce, (1,1), padding='same', activation='relu')(x)
    branch5 = layers.Conv2D(filters_5x5, (3,3), padding='same', activation='relu')(branch5)
    branch5 = layers.Conv2D(filters_5x5, (3,3), padding='same', activation='relu')(branch5)
    branch_pool = layers.MaxPooling2D((3,3), strides=(1,1), padding='same')(x)
    branch_pool = layers.Conv2D(filters_pool_proj, (1,1), padding='same', activation='relu')(branch_pool)
    out = layers.concatenate([branch1, branch3, branch5, branch_pool], axis=-1, name=name)
    return out

def build_inception_like(input_shape=(299,299,3), dropout_rate=0.4):
    inp = layers.Input(shape=input_shape)
    x = layers.Conv2D(32, (3,3), strides=(2,2), padding='valid', activation='relu')(inp)
    x = layers.Conv2D(32, (3,3), padding='valid', activation='relu')(x)
    x = layers.Conv2D(64, (3,3), padding='same', activation='relu')(x)
    x = layers.MaxPooling2D((3,3), strides=(2,2), padding='valid')(x)
    x = layers.Conv2D(80, (1,1), activation='relu')(x)
    x = layers.Conv2D(192, (3,3), padding='valid', activation='relu')(x)
    x = layers.MaxPooling2D((3,3), strides=(2,2), padding='valid')(x)

    x = inception_module(x, 64, 48, 64, 64, 96, 32, name="incept_1")
    x = inception_module(x, 64, 48, 64, 64, 96, 64, name="incept_2")
    x = layers.MaxPooling2D((3,3), strides=(2,2), padding='valid')(x)

    x = inception_module(x, 128, 96, 128, 96, 128, 128, name="incept_3")
    x = inception_module(x, 160, 112, 160, 112, 160, 128, name="incept_4")
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout_rate)(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(dropout_rate/2)(x)
    out = layers.Dense(1, activation='sigmoid')(x)  
    model = models.Model(inputs=inp, outputs=out, name="InceptionLike_binary")
    return model

def compile_and_train(model, train_gen, val_gen, epochs=EPOCHS):
    model.compile(
        optimizer=optimizers.Adam(learning_rate=LR),
        loss='binary_crossentropy',
        metrics=['accuracy', tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')]
    )
    from collections import Counter
    counter = Counter(train_gen.classes)
    majority = max(counter.values())
    class_weight = {cls: float(majority/count) for cls, count in counter.items()}
    cb = [
        callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
        callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-7),
        callbacks.ModelCheckpoint(MODEL_PATH, save_best_only=True, monitor='val_loss')
    ]
    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=epochs,
        class_weight=class_weight,
        callbacks=cb,
        verbose=1
    )
    return history

def evaluate_model(model, val_gen):
    val_gen.reset()
    preds = model.predict(val_gen, verbose=1).ravel()
    y_pred = (preds > 0.5).astype(int)
    y_true = val_gen.classes
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, zero_division=0)
    rec = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    cm = confusion_matrix(y_true, y_pred)
    print("Accuracy:", acc)
    print("Precision:", prec)
    print("Recall:", rec)
    print("F1:", f1)
    print("\nClassification report:\n", classification_report(y_true, y_pred, target_names=list(val_gen.class_indices.keys()), zero_division=0))
    plt.figure(figsize=(5,4))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=list(val_gen.class_indices.keys()), yticklabels=list(val_gen.class_indices.keys()))
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title("Confusion matrix")
    plt.show()
    meta = {"accuracy": float(acc), "precision": float(prec), "recall": float(rec), "f1": float(f1)}
    with open(METADATA_JSON, "w") as f:
        json.dump(meta, f, indent=2)
    return {"acc":acc, "prec":prec, "rec":rec, "f1":f1, "cm":cm}

def predict_image(model, image_path, class_indices_path=CLASS_INDICES_JSON):
    from tensorflow.keras.preprocessing import image
    img = image.load_img(image_path, target_size=IMG_SIZE)
    arr = image.img_to_array(img) / 255.0
    arr = np.expand_dims(arr, axis=0)
    prob = model.predict(arr)[0,0]
    pred = int(prob > 0.5)
    with open(class_indices_path, "r", encoding="utf-8") as f:
        cls = json.load(f)
    inv = {v:k for k,v in cls.items()}
    predicted_label = inv.get(pred, str(pred))
    return predicted_label, float(prob)

if __name__ == "__main__":
    assert os.path.exists(DATASET_DIR), f"DATASET_DIR not found: {DATASET_DIR}"
    train_gen, val_gen = create_generators(DATASET_DIR)
    model = build_inception_like(input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3), dropout_rate=0.4)
    model.summary() 
    history = compile_and_train(model, train_gen, val_gen, epochs=EPOCHS)
    results = evaluate_model(model, val_gen)
    model.save(MODEL_PATH)
    print("Model and metadata saved.")
    if os.path.exists(TEST_DIR):
        print("\n--- Predicting test images ---")
        test_datagen = ImageDataGenerator(rescale=1./255)
        test_gen = test_datagen.flow_from_directory(TEST_DIR, target_size=IMG_SIZE, batch_size=1, class_mode=None, shuffle=False)
        preds = model.predict(test_gen, verbose=1)
        pred_labels = (preds.ravel() > 0.5).astype(int)
        inv = {v:k for k,v in train_gen.class_indices.items()}
        for i, fname in enumerate(test_gen.filenames):
            print(f"{fname} -> {inv[pred_labels[i]]} (p={preds.ravel()[i]:.3f})")
    else:
        print("\nTEST_DIR not found. If you want to test images, create TEST_DIR")
# Out:
# 2025-10-27 20:03:55.886139: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761595436.144129      37 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761595436.220607      37 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 447 images belonging to 2 classes.
# Found 110 images belonging to 2 classes.
# I0000 00:00:1761595451.434970      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1761595451.435648      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "InceptionLike_binary"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 299, 299,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 149, 149,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 147, 147,  │      9,248 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 147, 147,  │     18,496 │ conv2d_1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 73, 73,    │          0 │ conv2d_2[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 73, 73,    │      5,200 │ max_pooling2d[0]… │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 71, 71,    │    138,432 │ conv2d_3[0][0]    │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 35, 35,    │          0 │ conv2d_4[0][0]    │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 35, 35,    │     12,352 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 35, 35,    │      9,264 │ max_pooling2d_1[… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 35, 35,    │     55,392 │ conv2d_8[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 35, 35,    │          0 │ max_pooling2d_1[… │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 35, 35,    │     12,352 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 35, 35,    │     27,712 │ conv2d_6[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 35, 35,    │     83,040 │ conv2d_9[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 35, 35,    │      6,176 │ max_pooling2d_2[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incept_1            │ (None, 35, 35,    │          0 │ conv2d_5[0][0],   │
# │ (Concatenate)       │ 256)              │            │ conv2d_7[0][0],   │
# │                     │                   │            │ conv2d_10[0][0],  │
# │                     │                   │            │ conv2d_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 35, 35,    │     16,448 │ incept_1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 35, 35,    │     12,336 │ incept_1[0][0]    │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 35, 35,    │     55,392 │ conv2d_15[0][0]   │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 35, 35,    │          0 │ incept_1[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 35, 35,    │     16,448 │ incept_1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 35, 35,    │     27,712 │ conv2d_13[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 35, 35,    │     83,040 │ conv2d_16[0][0]   │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 35, 35,    │     16,448 │ max_pooling2d_3[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incept_2            │ (None, 35, 35,    │          0 │ conv2d_12[0][0],  │
# │ (Concatenate)       │ 288)              │            │ conv2d_14[0][0],  │
# │                     │                   │            │ conv2d_17[0][0],  │
# │                     │                   │            │ conv2d_18[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 17, 17,    │          0 │ incept_2[0][0]    │
# │ (MaxPooling2D)      │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 17, 17,    │     27,744 │ max_pooling2d_4[… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 17, 17,    │     27,744 │ max_pooling2d_4[… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 17, 17,    │    110,720 │ conv2d_22[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 17, 17,    │          0 │ max_pooling2d_4[… │
# │ (MaxPooling2D)      │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 17, 17,    │     36,992 │ max_pooling2d_4[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 17, 17,    │    110,720 │ conv2d_20[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 17, 17,    │    147,584 │ conv2d_23[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 17, 17,    │     36,992 │ max_pooling2d_5[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incept_3            │ (None, 17, 17,    │          0 │ conv2d_19[0][0],  │
# │ (Concatenate)       │ 512)              │            │ conv2d_21[0][0],  │
# │                     │                   │            │ conv2d_24[0][0],  │
# │                     │                   │            │ conv2d_25[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 17, 17,    │     57,456 │ incept_3[0][0]    │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 17, 17,    │     57,456 │ incept_3[0][0]    │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 17, 17,    │    161,440 │ conv2d_29[0][0]   │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 17, 17,    │          0 │ incept_3[0][0]    │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 17, 17,    │     82,080 │ incept_3[0][0]    │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 17, 17,    │    161,440 │ conv2d_27[0][0]   │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 17, 17,    │    230,560 │ conv2d_30[0][0]   │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 17, 17,    │     65,664 │ max_pooling2d_6[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incept_4            │ (None, 17, 17,    │          0 │ conv2d_26[0][0],  │
# │ (Concatenate)       │ 608)              │            │ conv2d_28[0][0],  │
# │                     │                   │            │ conv2d_31[0][0],  │
# │                     │                   │            │ conv2d_32[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 608)       │          0 │ incept_4[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 608)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    155,904 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        257 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,077,137 (7.92 MB)
#  Trainable params: 2,077,137 (7.92 MB)
#  Non-trainable params: 0 (0.00 B)
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761595472.105928     112 service.cc:148] XLA service 0x781384235810 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761595472.106953     112 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761595472.106972     112 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761595473.837578     112 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1761595492.889844     112 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.4608 - loss: 0.6954 - precision: 0.4858 - recall: 0.8035 - val_accuracy: 0.5455 - val_loss: 0.6931 - val_precision: 0.5287 - val_recall: 0.8364 - learning_rate: 1.0000e-04
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.5013 - loss: 0.6943 - precision: 0.5056 - recall: 0.7804 - val_accuracy: 0.5000 - val_loss: 0.6926 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.4752 - loss: 0.6949 - precision: 0.4717 - recall: 0.8858 - val_accuracy: 0.5000 - val_loss: 0.6921 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.5180 - loss: 0.6935 - precision: 0.5122 - recall: 1.0000 - val_accuracy: 0.5000 - val_loss: 0.6916 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.5132 - loss: 0.6915 - precision: 0.5133 - recall: 0.9959 - val_accuracy: 0.5000 - val_loss: 0.6895 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 14s 967ms/step - accuracy: 0.5184 - loss: 0.6897 - precision: 0.5108 - recall: 0.9528 - val_accuracy: 0.5000 - val_loss: 0.6848 - val_precision: 0.5000 - val_recall: 0.9818 - learning_rate: 1.0000e-04
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.5404 - loss: 0.6937 - precision: 0.5325 - recall: 0.5947 - val_accuracy: 0.5727 - val_loss: 0.6834 - val_precision: 0.5465 - val_recall: 0.8545 - learning_rate: 1.0000e-04
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.5300 - loss: 0.6834 - precision: 0.5162 - recall: 0.8837 - val_accuracy: 0.5909 - val_loss: 0.6798 - val_precision: 0.5735 - val_recall: 0.7091 - learning_rate: 1.0000e-04
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6618 - loss: 0.6720 - precision: 0.6798 - recall: 0.6659 - val_accuracy: 0.5545 - val_loss: 0.6806 - val_precision: 0.5882 - val_recall: 0.3636 - learning_rate: 1.0000e-04
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.5843 - loss: 0.6709 - precision: 0.6098 - recall: 0.3789 - val_accuracy: 0.5818 - val_loss: 0.6728 - val_precision: 0.5529 - val_recall: 0.8545 - learning_rate: 1.0000e-04
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.5989 - loss: 0.6795 - precision: 0.5699 - recall: 0.6935 - val_accuracy: 0.6091 - val_loss: 0.6665 - val_precision: 0.5882 - val_recall: 0.7273 - learning_rate: 1.0000e-04
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.6238 - loss: 0.6648 - precision: 0.5984 - recall: 0.7624 - val_accuracy: 0.6273 - val_loss: 0.6659 - val_precision: 0.6400 - val_recall: 0.5818 - learning_rate: 1.0000e-04
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6420 - loss: 0.6614 - precision: 0.6622 - recall: 0.6808 - val_accuracy: 0.6000 - val_loss: 0.6683 - val_precision: 0.6341 - val_recall: 0.4727 - learning_rate: 1.0000e-04
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6054 - loss: 0.6697 - precision: 0.6558 - recall: 0.4769 - val_accuracy: 0.5636 - val_loss: 0.6661 - val_precision: 0.5412 - val_recall: 0.8364 - learning_rate: 1.0000e-04
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6004 - loss: 0.6723 - precision: 0.5774 - recall: 0.6180 - val_accuracy: 0.5727 - val_loss: 0.6712 - val_precision: 0.5426 - val_recall: 0.9273 - learning_rate: 1.0000e-04
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.6149 - loss: 0.6629 - precision: 0.5745 - recall: 0.8635 - val_accuracy: 0.6455 - val_loss: 0.6572 - val_precision: 0.6111 - val_recall: 0.8000 - learning_rate: 2.0000e-05
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.6841 - loss: 0.6356 - precision: 0.6881 - recall: 0.6895 - val_accuracy: 0.6364 - val_loss: 0.6479 - val_precision: 0.6364 - val_recall: 0.6364 - learning_rate: 2.0000e-05
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.5870 - loss: 0.6582 - precision: 0.6015 - recall: 0.5114 - val_accuracy: 0.6364 - val_loss: 0.6546 - val_precision: 0.6271 - val_recall: 0.6727 - learning_rate: 2.0000e-05
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6419 - loss: 0.6458 - precision: 0.6280 - recall: 0.6671 - val_accuracy: 0.6000 - val_loss: 0.6530 - val_precision: 0.5797 - val_recall: 0.7273 - learning_rate: 2.0000e-05
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.6709 - loss: 0.6360 - precision: 0.6789 - recall: 0.6954 - val_accuracy: 0.6545 - val_loss: 0.6537 - val_precision: 0.6491 - val_recall: 0.6727 - learning_rate: 2.0000e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 939ms/step
# Accuracy: 0.6363636363636364
# Precision: 0.6271186440677966
# Recall: 0.6727272727272727
# F1: 0.6491228070175439
#
# Classification report:
#                precision    recall  f1-score   support
#
#         cats       0.65      0.60      0.62        55
#         dogs       0.63      0.67      0.65        55
#
#     accuracy                           0.64       110
#    macro avg       0.64      0.64      0.64       110
# weighted avg       0.64      0.64      0.64       110
# Model and metadata saved.
#
# --- Predicting test images ---
# Found 140 images belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step
# cats/cat_1.jpg -> dogs (p=0.539)
# cats/cat_106.jpg -> cats (p=0.469)
# cats/cat_109.jpg -> cats (p=0.323)
# cats/cat_113.jpg -> dogs (p=0.616)
# cats/cat_114.jpg -> cats (p=0.399)
# cats/cat_116.jpg -> cats (p=0.305)
# cats/cat_118.jpg -> cats (p=0.466)
# cats/cat_119.jpg -> dogs (p=0.705)
# cats/cat_124.jpg -> cats (p=0.426)
# cats/cat_140.jpg -> cats (p=0.371)
# cats/cat_147.jpg -> cats (p=0.370)
# cats/cat_156.jpg -> cats (p=0.366)
# cats/cat_158.jpg -> cats (p=0.478)
# cats/cat_162.jpg -> cats (p=0.361)
# cats/cat_18.jpg -> dogs (p=0.815)
# cats/cat_190.jpg -> cats (p=0.436)
# cats/cat_203.jpg -> cats (p=0.351)
# cats/cat_223.jpg -> dogs (p=0.602)
# cats/cat_234.jpg -> cats (p=0.298)
# cats/cat_244.jpg -> dogs (p=0.609)
# cats/cat_251.jpg -> cats (p=0.324)
# cats/cat_255.jpg -> dogs (p=0.557)
# cats/cat_268.jpg -> cats (p=0.431)
# cats/cat_279.jpg -> cats (p=0.364)
# cats/cat_281.jpg -> dogs (p=0.525)
# cats/cat_290.jpg -> dogs (p=0.507)
# cats/cat_306.jpg -> dogs (p=0.651)
# cats/cat_313.jpg -> dogs (p=0.632)
# cats/cat_332.jpg -> dogs (p=0.562)
# cats/cat_341.jpg -> cats (p=0.338)
# cats/cat_342.jpg -> dogs (p=0.503)
# cats/cat_355.jpg -> cats (p=0.294)
# cats/cat_358.jpg -> cats (p=0.439)
# cats/cat_371.jpg -> dogs (p=0.709)
# cats/cat_375.jpg -> dogs (p=0.567)
# cats/cat_384.jpg -> cats (p=0.301)
# cats/cat_395.jpg -> cats (p=0.330)
# cats/cat_417.jpg -> cats (p=0.321)
# cats/cat_418.jpg -> cats (p=0.466)
# cats/cat_422.jpg -> dogs (p=0.527)
# cats/cat_430.jpg -> cats (p=0.425)
# cats/cat_433.jpg -> cats (p=0.298)
# cats/cat_446.jpg -> cats (p=0.362)
# cats/cat_464.jpg -> cats (p=0.301)
# cats/cat_468.jpg -> cats (p=0.301)
# cats/cat_473.jpg -> dogs (p=0.750)
# cats/cat_496.jpg -> cats (p=0.453)
# cats/cat_5.jpg -> dogs (p=0.604)
# cats/cat_504.jpg -> cats (p=0.290)
# cats/cat_520.jpg -> cats (p=0.328)
# cats/cat_523.jpg -> dogs (p=0.556)
# cats/cat_525.jpg -> dogs (p=0.605)
# cats/cat_528.jpg -> cats (p=0.478)
# cats/cat_538.jpg -> cats (p=0.458)
# cats/cat_542.jpg -> dogs (p=0.506)
# cats/cat_545.jpg -> cats (p=0.314)
# cats/cat_551.jpg -> cats (p=0.338)
# cats/cat_56.jpg -> dogs (p=0.540)
# cats/cat_564.jpg -> dogs (p=0.623)
# cats/cat_574.jpg -> cats (p=0.460)
# cats/cat_575.jpg -> cats (p=0.408)
# cats/cat_583.jpg -> cats (p=0.309)
# cats/cat_585.jpg -> dogs (p=0.576)
# cats/cat_586.jpg -> dogs (p=0.503)
# cats/cat_587.jpg -> cats (p=0.376)
# cats/cat_595.jpg -> dogs (p=0.613)
# cats/cat_60.jpg -> dogs (p=0.693)
# cats/cat_88.jpg -> dogs (p=0.660)
# cats/cat_94.jpg -> dogs (p=0.559)
# cats/cat_96.jpg -> cats (p=0.325)
# dogs/dog_114.jpg -> cats (p=0.415)
# dogs/dog_123.jpg -> dogs (p=0.583)
# dogs/dog_124.jpg -> cats (p=0.494)
# dogs/dog_130.jpg -> dogs (p=0.642)
# dogs/dog_141.jpg -> dogs (p=0.671)
# dogs/dog_142.jpg -> dogs (p=0.566)
# dogs/dog_147.jpg -> dogs (p=0.645)
# dogs/dog_150.jpg -> dogs (p=0.610)
# dogs/dog_155.jpg -> dogs (p=0.618)
# dogs/dog_159.jpg -> dogs (p=0.571)
# dogs/dog_168.jpg -> cats (p=0.382)
# dogs/dog_173.jpg -> dogs (p=0.524)
# dogs/dog_177.jpg -> cats (p=0.392)
# dogs/dog_181.jpg -> dogs (p=0.536)
# dogs/dog_191.jpg -> dogs (p=0.564)
# dogs/dog_194.jpg -> dogs (p=0.688)
# dogs/dog_196.jpg -> dogs (p=0.527)
# dogs/dog_197.jpg -> cats (p=0.399)
# dogs/dog_211.jpg -> dogs (p=0.682)
# dogs/dog_213.jpg -> dogs (p=0.535)
# dogs/dog_219.jpg -> cats (p=0.487)
# dogs/dog_227.jpg -> dogs (p=0.611)
# dogs/dog_229.jpg -> dogs (p=0.504)
# dogs/dog_236.jpg -> cats (p=0.303)
# dogs/dog_237.jpg -> dogs (p=0.625)
# dogs/dog_240.jpg -> cats (p=0.441)
# dogs/dog_244.jpg -> dogs (p=0.577)
# dogs/dog_258.jpg -> cats (p=0.411)
# dogs/dog_28.jpg -> dogs (p=0.564)
# dogs/dog_283.jpg -> dogs (p=0.558)
# dogs/dog_302.jpg -> dogs (p=0.559)
# dogs/dog_303.jpg -> dogs (p=0.773)
# dogs/dog_313.jpg -> dogs (p=0.583)
# dogs/dog_327.jpg -> dogs (p=0.624)
# dogs/dog_344.jpg -> cats (p=0.352)
# dogs/dog_354.jpg -> dogs (p=0.767)
# dogs/dog_355.jpg -> cats (p=0.315)
# dogs/dog_360.jpg -> dogs (p=0.549)
# dogs/dog_364.jpg -> dogs (p=0.503)
# dogs/dog_369.jpg -> dogs (p=0.502)
# dogs/dog_377.jpg -> dogs (p=0.646)
# dogs/dog_380.jpg -> dogs (p=0.618)
# dogs/dog_398.jpg -> dogs (p=0.660)
# dogs/dog_415.jpg -> cats (p=0.330)
# dogs/dog_421.jpg -> dogs (p=0.635)
# dogs/dog_43.jpg -> dogs (p=0.559)
# dogs/dog_44.jpg -> cats (p=0.390)
# dogs/dog_442.jpg -> dogs (p=0.567)
# dogs/dog_443.jpg -> dogs (p=0.510)
# dogs/dog_461.jpg -> dogs (p=0.521)
# dogs/dog_462.jpg -> dogs (p=0.650)
# dogs/dog_464.jpg -> dogs (p=0.562)
# dogs/dog_472.jpg -> dogs (p=0.546)
# dogs/dog_476.jpg -> dogs (p=0.659)
# dogs/dog_482.jpg -> dogs (p=0.501)
# dogs/dog_517.jpg -> cats (p=0.470)
# dogs/dog_518.jpg -> cats (p=0.405)
# dogs/dog_519.jpg -> cats (p=0.421)
# dogs/dog_520.jpg -> dogs (p=0.664)
# dogs/dog_521.jpg -> dogs (p=0.669)
# dogs/dog_522.jpg -> cats (p=0.446)
# dogs/dog_528.jpg -> dogs (p=0.605)
# dogs/dog_534.jpg -> dogs (p=0.558)
# dogs/dog_536.jpg -> dogs (p=0.561)
# dogs/dog_551.jpg -> dogs (p=0.515)
# dogs/dog_563.jpg -> dogs (p=0.522)
# dogs/dog_59.jpg -> cats (p=0.485)
# dogs/dog_68.jpg -> dogs (p=0.653)
# dogs/dog_75.jpg -> dogs (p=0.508)
# dogs/dog_89.jpg -> cats (p=0.465)
